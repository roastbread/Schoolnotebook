# %% [markdown]
# ### Import required libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create a New Folder
# The new folder will be created in the Current Directory.
# The saved outputs of this notebook are located in this folder.

# %%
import os

# Get current working directory
current_dir = os.getcwd()

print("Current directory:", current_dir)

# Name the new folder
Output_folder='Description_Cinderella_II_Dataset'
# Out:
# Current directory: C:\Users\ernil\OneDrive\Dokument\Schoolnotebook\Datamining\Project

# %%
## Create the output folder
folder_path = r''+Output_folder
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %% [markdown]
# ### Load the Dataset
# Import the dataset to this notebook.
# Then show how many rows and columns in this dataset

# %%
### df = pd.read_pickle('Data/Cinderella_II_Dataset.pkl')  ## if the data in Pickle file
df = pd.read_csv('Data/Cinderella_II_Dataset.csv') ## if the data in CSV file

df.shape
# Out:
# (243688, 48)

# %% [markdown]
# ### Data Information
# Show some description about the dataset, timeframe, number and names of rows and columns, data types and size

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243688 entries, 0 to 243687
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   engine_fuel_rate        243688 non-null  float64
#  1   accum_fuel_leg          243688 non-null  float64
#  2   engine_rpm              243688 non-null  float64
#  3   accelPedalPos           243688 non-null  float64
#  4   latitude                243688 non-null  float64
#  5   longitude               243688 non-null  float64
#  6   speedOverGround         243688 non-null  float64
#  7   courseOverGroundTrue    243688 non-null  float64
#  8   speedApparent           243688 non-null  float64
#  9   heading_magnetic        243688 non-null  float64
#  10  pitch                   243688 non-null  float64
#  11  roll                    243688 non-null  float64
#  12  rateOfTurn              243688 non-null  float64
#  13  course_heading_diff     243688 non-null  float64
#  14  magnetic_variation      243688 non-null  float64
#  15  windDirection_Onb       243688 non-null  float64
#  16  windSpeed_Onb           243688 non-null  float64
#  17  windSpeed_cpr           243688 non-null  float64
#  18  windDirection_cpr       243688 non-null  float64
#  19  windSpeed_sg            243688 non-null  float64
#  20  windDirection_sg        243688 non-null  float64
#  21  waveHeight              243688 non-null  float64
#  22  waveDirection           243688 non-null  float64
#  23  currentSpeed            243688 non-null  float64
#  24  currentDirection        243688 non-null  float64
#  25  Temp_2m                 243688 non-null  float64
#  26  Press_surf              243688 non-null  float64
#  27  Precip                  243688 non-null  float64
#  28  swellHeight             243688 non-null  float64
#  29  secondarySwellHeight    243688 non-null  float64
#  30  WaveSwell_ht            243688 non-null  float64
#  31  Swell_ht                243688 non-null  float64
#  32  Snow_depth              243688 non-null  float64
#  33  iceCover                243688 non-null  float64
#  34  Snow_fall               243688 non-null  float64
#  35  Bathymetry              243688 non-null  float64
#  36  distanceFromDock        243688 non-null  float64
#  37  distanceToNextDock      243688 non-null  float64
#  38  distanceToPreviousDock  243688 non-null  float64
#  39  delta_distance          243688 non-null  float64
#  40  accumDistLeg            243688 non-null  float64
#  41  Timestamp               243688 non-null  object
#  42  accum_time_leg          243688 non-null  float64
#  43  sailing_state           243688 non-null  object
#  44  closest_dock            243688 non-null  object
#  45  segment_state           243688 non-null  object
#  46  leg                     243688 non-null  object
#  47  RT_id                   243688 non-null  float64
# dtypes: float64(43), object(5)
# memory usage: 160.1 MB

# %% [markdown]
# ### Show Data Samples

# %%
df.head()
# Out:
#    engine_fuel_rate  accum_fuel_leg   engine_rpm  accelPedalPos   latitude  \
# 0         82.000000        0.013583  1326.416667       0.106413  59.401617
# 1        101.333333        0.036750  1340.500000       0.131053  59.401609
# 2        114.500000        0.069500  1379.500000       0.146299  59.401597
# 3        120.000000        0.103833  1423.166667       0.152447  59.401582
# 4        122.000000        0.134333  1423.083333       0.158249  59.401569
#
#    longitude  speedOverGround  courseOverGroundTrue  speedApparent  \
# 0  18.355397         0.448467              171.7957       4.662587
# 1  18.355403         0.589003              171.7957       4.363132
# 2  18.355410         0.742814              171.7957       4.006906
# 3  18.355416         0.900456              171.7957       4.046811
# 4  18.355422         1.056645              171.7957       4.165147
#
#    heading_magnetic  ...  distanceToPreviousDock  delta_distance  \
# 0          167.3953  ...               17.744368        0.192010
# 1          167.3953  ...               18.369153        0.228877
# 2          167.3953  ...               19.411825        0.274332
# 3          167.3953  ...               20.731121        0.331778
# 4          167.3953  ...               21.983082        0.388637
#
#    accumDistLeg            Timestamp  accum_time_leg  sailing_state  \
# 0      0.375416  2022-07-01 08:54:52            0.60   un_specified
# 1      1.025822  2022-07-01 08:54:53            1.50   un_specified
# 2      1.930372  2022-07-01 08:54:54            2.55   un_specified
# 3      3.011387  2022-07-01 08:54:55            3.60   un_specified
# 4      4.119830  2022-07-01 08:54:56            4.50   un_specified
#
#    closest_dock  segment_state            leg  RT_id
# 0       vaxholm        docking  vaxholm-sodra    0.0
# 1       vaxholm        docking  vaxholm-sodra    0.0
# 2       vaxholm        docking  vaxholm-sodra    0.0
# 3       vaxholm        docking  vaxholm-sodra    0.0
# 4       vaxholm        docking  vaxholm-sodra    0.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Data Description

# %%
df.columns
# Out:
# Index(['engine_fuel_rate', 'accum_fuel_leg', 'engine_rpm', 'accelPedalPos',
#        'latitude', 'longitude', 'speedOverGround', 'courseOverGroundTrue',
#        'speedApparent', 'heading_magnetic', 'pitch', 'roll', 'rateOfTurn',
#        'course_heading_diff', 'magnetic_variation', 'windDirection_Onb',
#        'windSpeed_Onb', 'windSpeed_cpr', 'windDirection_cpr', 'windSpeed_sg',
#        'windDirection_sg', 'waveHeight', 'waveDirection', 'currentSpeed',
#        'currentDirection', 'Temp_2m', 'Press_surf', 'Precip', 'swellHeight',
#        'secondarySwellHeight', 'WaveSwell_ht', 'Swell_ht', 'Snow_depth',
#        'iceCover', 'Snow_fall', 'Bathymetry', 'distanceFromDock',
#        'distanceToNextDock', 'distanceToPreviousDock', 'delta_distance',
#        'accumDistLeg', 'Timestamp', 'accum_time_leg', 'sailing_state',
#        'closest_dock', 'segment_state', 'leg', 'RT_id'],
#       dtype='object')

# %%
df
# Out:
#         engine_fuel_rate  accum_fuel_leg   engine_rpm  accelPedalPos  \
# 0              82.000000        0.013583  1326.416667       0.106413
# 1             101.333333        0.036750  1340.500000       0.131053
# 2             114.500000        0.069500  1379.500000       0.146299
# 3             120.000000        0.103833  1423.166667       0.152447
# 4             122.000000        0.134333  1423.083333       0.158249
# ...                  ...             ...          ...            ...
# 243683         28.375000       72.488531  1079.875000      -0.000833
# 243684         35.666667       72.498028  1081.500000       0.026666
# 243685         39.333333       72.507694  1081.416667       0.038610
# 243686         42.000000       72.519667  1080.562500       0.024791
# 243687         46.000000       72.530625  1080.500000       0.010833
#
#          latitude  longitude  speedOverGround  courseOverGroundTrue  \
# 0       59.401617  18.355397         0.448467            171.795700
# 1       59.401609  18.355403         0.589003            171.795700
# 2       59.401597  18.355410         0.742814            171.795700
# 3       59.401582  18.355416         0.900456            171.795700
# 4       59.401569  18.355422         1.056645            171.795700
# ...           ...        ...              ...                   ...
# 243683  59.401974  18.355802         0.087500            127.806862
# 243684  59.401974  18.355803         0.208333            173.826817
# 243685  59.401973  18.355803         0.208333            169.127583
# 243686  59.401972  18.355803         0.162500            171.542863
# 243687  59.401971  18.355803         0.150000            158.594700
#
#         speedApparent  heading_magnetic  ...  distanceToPreviousDock  \
# 0            4.662587        167.395300  ...               17.744368
# 1            4.363132        167.395300  ...               18.369153
# 2            4.006906        167.395300  ...               19.411825
# 3            4.046811        167.395300  ...               20.731121
# 4            4.165147        167.395300  ...               21.983082
# ...               ...               ...  ...                     ...
# 243683       7.480028        252.354950  ...            11179.399849
# 243684       8.205154        253.009533  ...            11179.395662
# 243685       8.477634        253.374350  ...            11179.390546
# 243686       8.435836        254.368200  ...            11179.378464
# 243687       8.289120        255.344350  ...            11179.360903
#
#         delta_distance  accumDistLeg            Timestamp  accum_time_leg  \
# 0             0.192010      0.375416  2022-07-01 08:54:52            0.60
# 1             0.228877      1.025822  2022-07-01 08:54:53            1.50
# 2             0.274332      1.930372  2022-07-01 08:54:54            2.55
# 3             0.331778      3.011387  2022-07-01 08:54:55            3.60
# 4             0.388637      4.119830  2022-07-01 08:54:56            4.50
# ...                ...           ...                  ...             ...
# 243683        0.023743  13140.684068  2022-11-06 15:22:27         1991.25
# 243684        0.017866  13140.753436  2022-11-06 15:22:28         1992.30
# 243685        0.015530  13140.801752  2022-11-06 15:22:29         1993.20
# 243686        0.016695  13140.857808  2022-11-06 15:22:30         1994.25
# 243687        0.020288  13140.913883  2022-11-06 15:22:31         1995.15
#
#         sailing_state  closest_dock  segment_state            leg  RT_id
# 0        un_specified       vaxholm        docking  vaxholm-sodra    0.0
# 1        un_specified       vaxholm        docking  vaxholm-sodra    0.0
# 2        un_specified       vaxholm        docking  vaxholm-sodra    0.0
# 3        un_specified       vaxholm        docking  vaxholm-sodra    0.0
# 4        un_specified       vaxholm        docking  vaxholm-sodra    0.0
# ...               ...           ...            ...            ...    ...
# 243683   un_specified       vaxholm        docking  sodra-vaxholm  123.0
# 243684   un_specified       vaxholm        docking  sodra-vaxholm  123.0
# 243685   un_specified       vaxholm        docking  sodra-vaxholm  123.0
# 243686   un_specified       vaxholm        docking  sodra-vaxholm  123.0
# 243687   un_specified       vaxholm        docking  sodra-vaxholm  123.0
#
# [243688 rows x 48 columns]

# %%
# st=stop

# %% [markdown]
# ### The Engine's Fuel Varaibles

# %%
df[['engine_fuel_rate','accum_fuel_leg', 'engine_rpm', 'accelPedalPos']].describe()
# Out:
#        engine_fuel_rate  accum_fuel_leg     engine_rpm  accelPedalPos
# count     243688.000000   243688.000000  243688.000000  243688.000000
# mean         212.532341       62.295982    1472.178615      -0.000306
# std          167.687644       45.309545     493.785546       0.055511
# min            7.000000        0.001125     567.000000      -0.578981
# 25%           62.666667       24.097479    1092.000000      -0.010444
# 50%          130.859375       54.669153    1390.333333       0.000000
# 75%          410.000000       98.923394    2007.875000       0.009583
# max          438.000000      162.213417    2021.500000       0.512523

# %% [markdown]
# ### Navigational Speed and Direction Variables

# %%
df[['latitude', 'longitude', 'speedOverGround', 'courseOverGroundTrue']].describe()
# Out:
#             latitude      longitude  speedOverGround  courseOverGroundTrue
# count  243688.000000  243688.000000    243688.000000         243688.000000
# mean       59.420199      18.429791         7.394861            178.397720
# std         0.011264       0.065625         3.350154             91.753745
# min        59.401001      18.349419         0.000000              0.048700
# 25%        59.411723      18.370545         4.470000             99.722948
# 50%        59.419432      18.415979         6.750000            171.795700
# 75%        59.425815      18.487057        10.800000            270.592938
# max        59.443989      18.557320        12.625933            359.892000

# %% [markdown]
# ### Other Navigational and Kinematic Variables

# %%
df[['speedApparent', 'heading_magnetic','pitch', 'roll', 
    'rateOfTurn','course_heading_diff', 'magnetic_variation']].describe()
# Out:
#        speedApparent  heading_magnetic          pitch           roll  \
# count  243688.000000     243688.000000  243688.000000  243688.000000
# mean       14.326352        173.105766       0.592706       0.462086
# std        12.135864         95.533964       4.222790       1.206473
# min         0.005466          0.000000      -8.713733      -7.098900
# 25%         5.142269         95.370250      -3.949075      -0.446900
# 50%         9.842504        167.395300       3.570925       0.395300
# 75%        21.048836        268.671017       4.272850       1.332592
# max        53.328574        359.892000       8.747650       7.194925
#
#           rateOfTurn  course_heading_diff  magnetic_variation
# count  243688.000000        243688.000000       243688.000000
# mean       -0.013116            -0.118314            5.569121
# std         6.023352             1.650540            0.121316
# min       -48.941460            -3.126736            5.494700
# 25%        -2.303667            -1.802935            5.494700
# 50%        -0.051312            -0.153844            5.494700
# 75%         2.300333             1.240678            5.597800
# max        45.893333             3.122324            5.895700

# %% [markdown]
# ### Weather Variables
#
# Onb, stands for wind variables which are from Onboard data (from the vessel sensors)
# cpr, stands for wind variables which are from Climate Data Store - Copernicus data, external source [https://cds.climate.copernicus.eu](https://cds.climate.copernicus.eu)
# sg, stands for wind variables which are from Stormglass Data, external source [https://stormglass.io](https://stormglass.io)
# No subscript, means this weather variable has a unique name and no need to distinguish it from other variables, the variable either from Stormglass or Copernicus sources.

# %%
df[['windDirection_Onb','windSpeed_Onb','windSpeed_cpr','windDirection_cpr','windSpeed_sg','windDirection_sg',
    'waveHeight', 'waveDirection','currentSpeed', 'currentDirection']].describe()
# Out:
#        windDirection_Onb  windSpeed_Onb  windSpeed_cpr  windDirection_cpr  \
# count      243688.000000  243688.000000  243688.000000      243688.000000
# mean          176.315674      10.716105       4.409971         162.419155
# std            96.435665       9.002272       1.725013          90.269098
# min             0.000000       0.000000       0.900089           2.674805
# 25%           101.645594       3.775000       3.236436          86.948267
# 50%           174.893483       7.006667       4.159589         173.376855
# 75%           261.916913      16.560000       5.511238         221.247810
# max           359.892000      42.230000       9.624209         358.765230
#
#         windSpeed_sg  windDirection_sg     waveHeight  waveDirection  \
# count  243688.000000     243688.000000  243688.000000  243688.000000
# mean        2.594258        209.225989       0.471070     173.236515
# std         1.090935         94.947272       0.430175      87.886709
# min         0.517167         10.000000       0.000000       1.335678
# 25%         1.879382        137.909583       0.166633     128.625175
# 50%         2.515681        204.458750       0.359423     195.143195
# 75%         3.174604        282.243125       0.600699     225.578107
# max         6.730722        352.630000       1.992446     357.737120
#
#         currentSpeed  currentDirection
# count  243688.000000     243688.000000
# mean        0.025071        112.596983
# std         0.017819         90.611194
# min         0.000000          0.000000
# 25%         0.010000          0.000000
# 50%         0.020697        180.000000
# 75%         0.038953        180.000000
# max         0.080000        335.150000

# %% [markdown]
# ### Other Weather and Bathymetry Variables
# From external sources, Stormgalass and Copernicus

# %%
df[['Temp_2m', 'Press_surf', 'Precip',
    'swellHeight', 'secondarySwellHeight',
    'WaveSwell_ht', 'Swell_ht', 
    'Snow_depth', 'iceCover','Snow_fall',  
    'Bathymetry']].describe()
# Out:
#              Temp_2m     Press_surf        Precip    swellHeight  \
# count  243688.000000  243688.000000  2.436880e+05  243688.000000
# mean       18.323781  101255.791354  8.677141e-05       0.274971
# std         3.825181     581.738206  3.031685e-04       0.246447
# min         5.651520   99792.055000 -4.656613e-10       0.070000
# 25%        17.330750  100907.547500 -4.656613e-10       0.171033
# 50%        19.396744  101287.160000  3.691407e-06       0.220000
# 75%        20.656494  101609.822500  4.002512e-05       0.290000
# max        24.595856  102811.990000  2.678088e-03       1.990925
#
#        secondarySwellHeight   WaveSwell_ht       Swell_ht  Snow_depth  \
# count         243688.000000  243688.000000  243688.000000    243688.0
# mean               0.105593       0.677725       0.409934         0.0
# std                0.045346       0.391012       0.177827         0.0
# min                0.050000       0.246199       0.066640         0.0
# 25%                0.073750       0.438071       0.281689         0.0
# 50%                0.090000       0.562769       0.373883         0.0
# 75%                0.126056       0.754505       0.511370         0.0
# max                0.260000       2.153362       1.104863         0.0
#
#        iceCover     Snow_fall  Bathymetry
# count  243688.0  2.436880e+05    243688.0
# mean        0.0 -5.820766e-11        30.0
# std         0.0  2.573571e-22         0.0
# min         0.0 -5.820766e-11        30.0
# 25%         0.0 -5.820766e-11        30.0
# 50%         0.0 -5.820766e-11        30.0
# 75%         0.0 -5.820766e-11        30.0
# max         0.0 -5.820766e-11        30.0

# %% [markdown]
# ### Locational (Space Domain) Variables
# Including the Latitude and Longitude variables which have already been listed with the navigational variables

# %%
df[['distanceFromDock', 'distanceToNextDock', 'distanceToPreviousDock', 'delta_distance', 'accumDistLeg']]
# Out:
#         distanceFromDock  distanceToNextDock  distanceToPreviousDock  \
# 0              17.744368        11204.459658               17.744368
# 1              18.369153        11204.170199               18.369153
# 2              19.411825        11203.870746               19.411825
# 3              20.731121        11203.610745               20.731121
# 4              21.983082        11203.370234               21.983082
# ...                  ...                 ...                     ...
# 243683         28.101088           28.101088            11179.399849
# 243684         28.050513           28.050513            11179.395662
# 243685         28.005061           28.005061            11179.390546
# 243686         27.939003           27.939003            11179.378464
# 243687         27.853042           27.853042            11179.360903
#
#         delta_distance  accumDistLeg
# 0             0.192010      0.375416
# 1             0.228877      1.025822
# 2             0.274332      1.930372
# 3             0.331778      3.011387
# 4             0.388637      4.119830
# ...                ...           ...
# 243683        0.023743  13140.684068
# 243684        0.017866  13140.753436
# 243685        0.015530  13140.801752
# 243686        0.016695  13140.857808
# 243687        0.020288  13140.913883
#
# [243688 rows x 5 columns]

# %% [markdown]
# ### Time (Time Domain) Varaibles
# Note: The index of the dataset is similar to the Timestamp variable

# %%
df[['Timestamp', 'accum_time_leg']].describe()
# Out:
#        accum_time_leg
# count   243688.000000
# mean       985.519364
# std        572.829142
# min          0.300000
# 25%        491.100000
# 50%        982.350000
# 75%       1473.750000
# max       2322.150000

# %% [markdown]
# ### Additional Miscellaneous Variables
# These variables are labels and flags describtes the status for the vessel's trip in different segments.
# They are including some categorical variables.

# %%
### Categorical Variables

df[['sailing_state','closest_dock','segment_state','leg']].describe()

# df[['sailing_state','closest_dock','segment_state','leg']].head()
# df[['sailing_state','closest_dock','segment_state','leg']].tail()
# Out:
#        sailing_state closest_dock segment_state            leg
# count         243688       243688        243688         243688
# unique             2            3             3              2
# top     un_specified    kastellet      cruising  sodra-vaxholm
# freq          243270       137356        171891         134725

# %%
### Numerical Variable(s)

df['RT_id'].describe()
# Out:
# count    243688.000000
# mean         61.976753
# std          35.752570
# min           0.000000
# 25%          31.000000
# 50%          62.000000
# 75%          93.000000
# max         123.000000
# Name: RT_id, dtype: float64

# %%
#st=stop

# %% [markdown]
# ### Example of Data Visualization
# Plot all the vessel's routes and save the output plot in the the created output folder

# %%
# Create a scatter plot of latitude and longitude to visualize the ferry's path
fig = plt.figure(figsize=(10,7))
plt.scatter(df['longitude'], df['latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()

plt.savefig(Output_folder+'/Scatter_dforig_lat_lon_paths'+'.png', dpi=500)  

plt.show()

# %%
df.shape
# Out:
# (243688, 48)

# %%
df.columns
# Out:
# Index(['engine_fuel_rate', 'accum_fuel_leg', 'engine_rpm', 'accelPedalPos',
#        'latitude', 'longitude', 'speedOverGround', 'courseOverGroundTrue',
#        'speedApparent', 'heading_magnetic', 'pitch', 'roll', 'rateOfTurn',
#        'course_heading_diff', 'magnetic_variation', 'windDirection_Onb',
#        'windSpeed_Onb', 'windSpeed_cpr', 'windDirection_cpr', 'windSpeed_sg',
#        'windDirection_sg', 'waveHeight', 'waveDirection', 'currentSpeed',
#        'currentDirection', 'Temp_2m', 'Press_surf', 'Precip', 'swellHeight',
#        'secondarySwellHeight', 'WaveSwell_ht', 'Swell_ht', 'Snow_depth',
#        'iceCover', 'Snow_fall', 'Bathymetry', 'distanceFromDock',
#        'distanceToNextDock', 'distanceToPreviousDock', 'delta_distance',
#        'accumDistLeg', 'Timestamp', 'accum_time_leg', 'sailing_state',
#        'closest_dock', 'segment_state', 'leg', 'RT_id'],
#       dtype='object')
